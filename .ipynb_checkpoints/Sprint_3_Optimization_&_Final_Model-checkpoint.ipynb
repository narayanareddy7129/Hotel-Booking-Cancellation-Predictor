# %% [markdown]
# # Hotel Booking Cancellation Prediction
# ## Sprint 3: Optimization & Final Model
# **Goal: Improve model performance and reliability**

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, classification_report,
ConfusionMatrixDisplay, roc_auc_score, roc_curve)

# %%
from sklearn.ensemble import StackingClassifier

# %%
pd.set_option("display.max_columns",None)

# %% [markdown]
# # Load the data

# %%
df_pp = pd.read_csv(r'C:\Users\laksh\ML\ML Project\preprocessed_df')
print('Shape:',df_pp.shape)

X = df_pp.drop('remainder__is_canceled',axis=1)
y = df_pp['remainder__is_canceled']

X.drop(y[y.isna()].index,inplace=True)
y.drop(y[y.isna()].index,inplace=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Shape: (6774, 234)
# Train: (5418, 233), Test: (1355, 233)

# %% [markdown]
# ---
# # Step 1: Feature Engineering
# Creating new useful features from the exitsing data

# %%
# Work on a copy
X_fe = X.copy()

# %% [markdown]
# ### 1. Total stay nights

# %%
X_fe['fe__total_nights'] = X_fe['sc__stays_in_week_nights'] + X_fe['sc__stays_in_weekend_nights']

# %% [markdown]
# ### 2. Cancellation history ratio  (previous cancellations / total previous bookings)

# %%
total_prev = X_fe['sc__previous_cancellations'] + X_fe['sc__previous_bookings_not_canceled']
X_fe['fe__cancel_ratio'] = X_fe['sc__previous_cancellations'] / (total_prev + 1)

# %% [markdown]
# ### 3. Interaction: lead_time × cancel_ratio (high lead time + history of cancellation)

# %%
X_fe['fe__lead_x_cancel'] = X_fe['sc__lead_time_log'] * X_fe['fe__cancel_ratio']

# %% [markdown]
# ### 4. Waiting days flag (was the customer on a waitlist?)

# %%
X_fe['fe__was_waitlisted'] = (X_fe['sc__days_in_waiting_list'] > 0).astype(int)

# %%
print('New features added:', ['fe__total_nights', 'fe__cancel_ratio', 'fe__lead_x_cancel', 'fe__was_waitlisted'])
print('New shape:', X_fe.shape)
# Out:
# New features added: ['fe__total_nights', 'fe__cancel_ratio', 'fe__lead_x_cancel', 'fe__was_waitlisted']
# New shape: (6773, 237)

# %% [markdown]
# ### Check correlation of new features with target

# %%
fe_corr = pd.DataFrame({
    'Feature': ['fe__total_nights', 'fe__cancel_ratio', 'fe__lead_x_cancel', 'fe__was_waitlisted'],
    'Correlation with Target': [
        X_fe['fe__total_nights'].corr(y),
        X_fe['fe__cancel_ratio'].corr(y),
        X_fe['fe__lead_x_cancel'].corr(y),
        X_fe['fe__was_waitlisted'].corr(y)
    ]
}).sort_values('Correlation with Target', key=abs, ascending=False)

print(fe_corr.to_string(index=False))
# Out:
#            Feature  Correlation with Target
# fe__was_waitlisted                -0.089593
#  fe__lead_x_cancel                -0.076507
#   fe__total_nights                 0.000165
#   fe__cancel_ratio                      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_df = X_fe[['fe__total_nights',
                'fe__cancel_ratio',
                'fe__lead_x_cancel',
                'fe__was_waitlisted']].copy()

corr_df['target'] = y

sns.heatmap(
    corr_df.corr(),
    annot=True,
    cmap='coolwarm'
)
plt.show()

# %% [markdown]
# ---
# ### Save Feature Engineering Logic (for Sprint 4 Pipeline)
#
# The 4 engineered features above were created with inline pandas code. So that Sprint 4 can **replay the exact same transformations** inside an end-to-end `Pipeline`, we save this logic as a reusable scikit-learn transformer class (`FeatureEngineer`) in `src/feature_engineering.py`. We also define a `FeatureSelector` transformer here, which we'll use after Step 2 (Feature Selection) to keep only the top-N columns.

# %%
import os

os.makedirs('src', exist_ok=True)

feature_engineering_code = '''
from sklearn.base import BaseEstimator, TransformerMixin


class FeatureEngineer(BaseEstimator, TransformerMixin):
    \"\"\"
    Adds the Sprint 3 engineered features on top of the Sprint 1
    preprocessed columns:
      - fe__total_nights
      - fe__cancel_ratio
      - fe__lead_x_cancel
      - fe__was_waitlisted

    Designed to be used as a step inside an sklearn Pipeline, placed
    AFTER the preprocessor (ColumnTransformer) and BEFORE the model.
    \"\"\"

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()

        X['fe__total_nights'] = X['sc__stays_in_week_nights'] + X['sc__stays_in_weekend_nights']

        total_prev = X['sc__previous_cancellations'] + X['sc__previous_bookings_not_canceled']
        X['fe__cancel_ratio'] = X['sc__previous_cancellations'] / (total_prev + 1)

        X['fe__lead_x_cancel'] = X['sc__lead_time_log'] * X['fe__cancel_ratio']

        X['fe__was_waitlisted'] = (X['sc__days_in_waiting_list'] > 0).astype(int)

        return X


class FeatureSelector(BaseEstimator, TransformerMixin):
    \"\"\"
    Selects a fixed list of columns (the top-N features chosen in
    Sprint 3 via feature importance). Used as the final preprocessing
    step before the model in the Sprint 4 pipeline.
    \"\"\"

    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[self.columns]
'''

with open('src/feature_engineering.py', 'w') as f:
    f.write(feature_engineering_code)

print('src/feature_engineering.py written')

# %%
# Quick sanity check: verify the saved class reproduces the same features
import sys
sys.path.append('src')
from feature_engineering import FeatureEngineer

fe_check = FeatureEngineer().fit_transform(X.copy())
print('Columns match manual FE:', 
      set(['fe__total_nights','fe__cancel_ratio','fe__lead_x_cancel','fe__was_waitlisted'])
      .issubset(set(fe_check.columns)))
print(fe_check[['fe__total_nights','fe__cancel_ratio','fe__lead_x_cancel','fe__was_waitlisted']].head(3))

# %% [markdown]
#   # Step 2: Feature Selection

# %%
# Train-test split on engineered features
X_train_fe, X_test_fe, y_train_fe, y_test_fe = train_test_split(
    X_fe, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# **Feature Importance via Random Forest**

# %%
rf_selector = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
rf_selector.fit(X_train_fe, y_train_fe)

feat_imp = pd.Series(rf_selector.feature_importances_, index=X_fe.columns)
feat_imp_sorted = feat_imp.sort_values(ascending=False)

# %%
print("Top 20 features by importance:")
print(feat_imp_sorted.head(20))
# Out:
# Top 20 features by importance:
# ohe__country_PRT                      0.128868
# sc__adr_capped                        0.116440
# sc__lead_time_log                     0.102207
# fe__lead_x_cancel                     0.098010
# fe__total_nights                      0.054327
# ohe__country_GBR                      0.046954
# sc__stays_in_week_nights              0.042845
# ohe__market_segment_Online TA         0.038882
# sc__stays_in_weekend_nights           0.026397
# ohe__customer_type_Transient          0.019904
# ohe__arrival_date_month_July          0.017609
# ohe__market_segment_Offline TA/TO     0.017132
# sc__adults                            0.015185
# ohe__arrival_date_month_August        0.012966
# ohe__country_IRL                      0.012745
# ohe__arrival_date_month_October       0.012715
# ohe__customer_type_Transient-Party    0.012541
# ohe__assigned_room_type_D             0.011440
# ohe__country_ESP                      0.011083
# ohe__reserved_room_type_D             0.011056
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
feat_imp_sorted.head(20).plot(kind='bar', color='#3498db', edgecolor='black')
plt.title('Top 20 Feature Importances (Random Forest)', fontsize=13, fontweight='bold')
plt.ylabel('Importance Score')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Use top-N features based on importance**

# %%
top_n = 30

feat_imp_sorted = feat_imp.sort_values(ascending=False)

top_features = feat_imp_sorted.index

X_train_sel = X_train_fe[top_features]
X_test_sel  = X_test_fe[top_features]

# %% [markdown]
# # Step 3: Hyperparameter Tuning

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.50)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.12)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 11.2 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.9.0

# %%
import pandas as pd
import optuna

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### 1. Create Objective Function

# %%
def objective(trial):

    n_estimators = trial.suggest_int(
        'n_estimators',
        50,
        300
    )

    max_depth = trial.suggest_int(
        'max_depth',
        2,
        30
    )

    min_samples_split = trial.suggest_int(
        'min_samples_split',
        2,
        10
    )
    min_samples_leaf = trial.suggest_int(
        'min_samples_leaf',
        1,
        5
    )

    model = RandomForestClassifier(

        n_estimators=n_estimators,

        max_depth=max_depth,

        min_samples_split=min_samples_split,

        random_state=42
    )

    score = cross_val_score(

        model,

        X_train_sel,

        y_train_fe,

        cv=5,

        scoring='accuracy'
    ).mean()

    return score

# %% [markdown]
# ### 2. Create Study

# %%
study = optuna.create_study(

    direction='maximize'
)
# Out:
# [I 2026-06-12 04:04:12,063] A new study created in memory with name: no-name-02c20a42-f31a-4d43-b627-969118f5787e

# %% [markdown]
# ### 5. Start Optimization

# %%
study.optimize(

    objective,

    n_trials=30
)
# Out:
# [I 2026-06-12 04:05:28,945] Trial 0 finished with value: 0.7659593003710917 and parameters: {'n_estimators': 115, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.7659593003710917.
# [I 2026-06-12 04:06:05,539] Trial 1 finished with value: 0.7835288646355663 and parameters: {'n_estimators': 56, 'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.7835288646355663.
# [I 2026-06-12 04:07:23,341] Trial 2 finished with value: 0.7848947636254527 and parameters: {'n_estimators': 114, 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.7848947636254527.
# [I 2026-06-12 04:09:09,373] Trial 3 finished with value: 0.7836870138971683 and parameters: {'n_estimators': 160, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.7848947636254527.
# [I 2026-06-12 04:10:24,499] Trial 4 finished with value: 0.765269155602053 and parameters: {'n_estimators': 154, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.7848947636254527.
# [I 2026-06-12 04:12:43,693] Trial 5 finished with value: 0.7842621459074249 and parameters: {'n_estimators': 211, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 2 with value: 0.7848947636254527.
# [I 2026-06-12 04:15:11,874] Trial 6 finished with value: 0.7755492358968261 and parameters: {'n_estimators': 258, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.7848947636254527.
# [I 2026-06-12 04:18:48,341] Trial 7 finished with value: 0.7925437167293508 and parameters: {'n_estimators': 274, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.7925437167293508.
# [I 2026-06-12 04:22:18,251] Trial 8 finished with value: 0.788647337565124 and parameters: {'n_estimators': 289, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.7925437167293508.
# [I 2026-06-12 04:24:56,463] Trial 9 finished with value: 0.7730475130465052 and parameters: {'n_estimators': 288, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 7 with value: 0.7925437167293508.
# [I 2026-06-12 04:25:17,399] Trial 10 finished with value: 0.7275419516314068 and parameters: {'n_estimators': 222, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 7 with value: 0.7925437167293508.
# [I 2026-06-12 04:29:33,843] Trial 11 finished with value: 0.7942834185546703 and parameters: {'n_estimators': 293, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 11 with value: 0.7942834185546703.
# [I 2026-06-12 04:33:03,430] Trial 12 finished with value: 0.7947291265863337 and parameters: {'n_estimators': 240, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:36:18,637] Trial 13 finished with value: 0.7939671003934274 and parameters: {'n_estimators': 236, 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:39:06,812] Trial 14 finished with value: 0.7941971507169358 and parameters: {'n_estimators': 191, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:42:14,030] Trial 15 finished with value: 0.790315177604615 and parameters: {'n_estimators': 249, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:46:14,273] Trial 16 finished with value: 0.7934926453735546 and parameters: {'n_estimators': 296, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:47:12,375] Trial 17 finished with value: 0.7487347909202597 and parameters: {'n_estimators': 189, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:50:34,754] Trial 18 finished with value: 0.7905308497829042 and parameters: {'n_estimators': 268, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.7947291265863337.
# [I 2026-06-12 04:53:45,384] Trial 19 finished with value: 0.7947435109330387 and parameters: {'n_estimators': 234, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 04:56:11,244] Trial 20 finished with value: 0.7899413354931042 and parameters: {'n_estimators': 199, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 04:59:15,500] Trial 21 finished with value: 0.792874392364193 and parameters: {'n_estimators': 233, 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:02:41,356] Trial 22 finished with value: 0.794211532996479 and parameters: {'n_estimators': 247, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:06:09,649] Trial 23 finished with value: 0.7923711975911776 and parameters: {'n_estimators': 270, 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:10:00,857] Trial 24 finished with value: 0.792931903911489 and parameters: {'n_estimators': 300, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:12:31,387] Trial 25 finished with value: 0.7879284695802384 and parameters: {'n_estimators': 218, 'max_depth': 24, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:14:55,618] Trial 26 finished with value: 0.7940821431260584 and parameters: {'n_estimators': 172, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:18:02,291] Trial 27 finished with value: 0.7935357839435364 and parameters: {'n_estimators': 241, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:20:38,491] Trial 28 finished with value: 0.7790429990882265 and parameters: {'n_estimators': 271, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 19 with value: 0.7947435109330387.
# [I 2026-06-12 05:21:16,645] Trial 29 finished with value: 0.7486053834789623 and parameters: {'n_estimators': 117, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 19 with value: 0.7947435109330387.

# %%
best_param=study.best_params
best_param
# Out:
# {'n_estimators': 234,
#  'max_depth': 30,
#  'min_samples_split': 4,
#  'min_samples_leaf': 3}

# %%
study.best_value
# Out:
# 0.7947435109330387

# %% [markdown]
# # Ensemble Learning

# %%
stack = StackingClassifier(
    estimators=[
        ('rf', RandomForestClassifier(n_estimators= 194,
                                      max_depth= 30,
                                      min_samples_split= 7,
                                      min_samples_leaf= 4)),
        ('dt', DecisionTreeClassifier()),
        ('nb', GaussianNB())
    ],
    final_estimator=LogisticRegression()
)

# %%
stack.fit(X_train_sel, y_train_fe)
# Out:
# StackingClassifier(estimators=[('rf',
#                                 RandomForestClassifier(max_depth=30,
#                                                        min_samples_leaf=4,
#                                                        min_samples_split=7,
#                                                        n_estimators=194)),
#                                ('dt', DecisionTreeClassifier()),
#                                ('nb', GaussianNB())],
#                    final_estimator=LogisticRegression())

# %%
y_pred = stack.predict(X_test_sel)

# %%
pred=stack.predict(X_train_sel)
accuracy_score(y_train_fe,pred)
# Out:
# 0.9337393872277593

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8715867158671586

# %% [markdown]
# # Final Model

# %%
final_model = stack

# %%
pred=final_model.predict(X_train_sel)
accuracy_score(y_train_fe,pred)
# Out:
# 0.9337393872277593

# %%
y_pred = final_model.predict(X_test_sel)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8715867158671586

# %% [markdown]
# ---
# # Step 4: Model Serialization (for Sprint 4 Pipeline)

# %%
# Quick sanity check: verify the saved class reproduces the same features
import sys
sys.path.append('src')
from feature_engineering import FeatureEngineer

fe_check = FeatureEngineer().fit_transform(X.copy())
print('Columns match manual FE:', 
      set(['fe__total_nights','fe__cancel_ratio','fe__lead_x_cancel','fe__was_waitlisted'])
      .issubset(set(fe_check.columns)))
print(fe_check[['fe__total_nights','fe__cancel_ratio','fe__lead_x_cancel','fe__was_waitlisted']].head(3))

# %%
# Verify everything reloads correctly
loaded_model = joblib.load('models/final_model.pkl')
with open('models/selected_features.json') as f:
    loaded_features = json.load(f)

check_pred = loaded_model.predict(X_test_sel[loaded_features][:5])
print('Reload check predictions:', check_pred)
print('Sprint 3 artifacts ready for Sprint 4:')
print('  - models/preprocessor.pkl       (from Sprint 1)')
print('  - src/feature_engineering.py    (FeatureEngineer, FeatureSelector)')
print('  - models/final_model.pkl        (Stacking Classifier)')
print('  - models/selected_features.json (top 30 feature names)')
